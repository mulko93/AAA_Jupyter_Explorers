# %% [markdown]
# # Merge Hexagon Chunks
#
# This notebook merges the created hexagon files to create a Trips_Hexagons.csv including all trips each with its corresponding hexagons.
#
# ### What is done?
# 1. Load hexagon chunk files created on Mac & merge them into single file
# 2. Save file on disk
#     - file is already set on gitignore
#
# ### Input
# - data/output/trips-hexagons/trips-hexagons-{id}.csv
#     - (Multiple chunkfiles, each with antoher number as id)
#
# ### Output
# - data/output/Trips_Hexagons.csv
#
# ---------------------------------------------------------

# %% [markdown]
# ## 1. Load hexagon chunk files created on Mac & merge them into single file

# %%
import pandas as pd
import os
import glob

# %%
path_trips_hex_chunks=os.path.join(os.getcwd(), "..", "data", "output", "trips-hexagons")

print(path_trips_hex_chunks)
# Out:
# /Users/mstroh/PycharmProjects/AAA_Jupyter_Explorers/notebooks/../data/output/trips-hexagons

# %%
directors = glob.glob(path_trips_hex_chunks)

all_files = []
for director in directors:
    all_files=all_files+glob.glob(director+"/*.csv")
    
li = []

for filename in all_files:
    df_read = pd.read_csv(filename, index_col=None, header=0)
    li.append(df_read)

df = pd.concat(li, axis=0, ignore_index=True)

# %% [markdown]
# ## 2. Save file on disk

# %%
if "Unnamed: 0" in df.columns:
    df = df.drop("Unnamed: 0", axis=1)

# %%
df
# Out:
#         p_spot_start b_lock_types_start  p_maintenance_start  \
# 0               True         frame_lock                False
# 1               True         frame_lock                False
# 2              False         frame_lock                False
# 3               True         frame_lock                False
# 4               True         frame_lock                False
# ...              ...                ...                  ...
# 567434         False         frame_lock                False
# 567435          True         frame_lock                False
# 567436         False         frame_lock                False
# 567437          True         frame_lock                False
# 567438          True         frame_lock                False
#
#         p_bike_racks_start  p_place_type_start  p_number_start  p_uid_start  \
# 0                        0                   0          4395.0       264602
# 1                        0                   0          4395.0       264602
# 2                        0                  12             0.0     23395291
# 3                        0                   0          4384.0       264588
# 4                        0                   0          4302.0         2985
# ...                    ...                 ...             ...          ...
# 567434                   0                  12             0.0     20236818
# 567435                   4                   0          4429.0       300560
# 567436                   0                  12             0.0     20213159
# 567437                   0                   0          4426.0        27113
# 567438                   0                   0          4394.0       264601
#
#         b_number_start  p_free_racks_start  b_boardcomputer_start  ...  \
# 0                93547                   0             7551004173  ...
# 1                93667                   0             7551003158  ...
# 2                93780                   0             7551015363  ...
# 3                93155                   0             7551004083  ...
# 4                93869                   0             7551012807  ...
# ...                ...                 ...                    ...  ...
# 567434           93864                   0             7551012852  ...
# 567435           93520                   3             7551005318  ...
# 567436           93880                   0             7551012909  ...
# 567437           93198                   0             7551003786  ...
# 567438           93781                   0             7551002466  ...
#
#         p_lat_end  air_deg  air_hum  rain_mm  rain_yn sun_hour  wind_ms  \
# 0       51.033352     22.7     51.3      0.0      0.0     60.0      4.0
# 1       51.033352     22.7     51.3      0.0      0.0     60.0      4.0
# 2       51.051869     22.7     51.3      0.0      0.0     60.0      4.0
# 3       51.030220     22.7     51.3      0.0      0.0     60.0      4.0
# 4       51.052569     22.7     51.3      0.0      0.0     60.0      4.0
# ...           ...      ...      ...      ...      ...      ...      ...
# 567434  51.056698     18.6     65.0      0.0      0.0      0.0      3.0
# 567435  51.116994     18.6     65.0      0.0      0.0      0.0      3.0
# 567436  51.046444     18.6     65.0      0.0      0.0      0.0      3.0
# 567437  51.049181     18.6     65.0      0.0      0.0      0.0      3.0
# 567438  51.058586     18.6     65.0      0.0      0.0      0.0      3.0
#
#         trip_duration  h3_hex_id_start    h3_hex_id_end
# 0                58.0  871f1b096ffffff  871f1b461ffffff
# 1                58.0  871f1b096ffffff  871f1b461ffffff
# 2                28.0  871f1b464ffffff  871f1b464ffffff
# 3                27.0  871f1b460ffffff  871f1b460ffffff
# 4                 9.0  871f1b54bffffff  871f1b464ffffff
# ...               ...              ...              ...
# 567434            2.0  871f1b54affffff  871f1b54affffff
# 567435            2.0  871f1b0b6ffffff  871f1b0b6ffffff
# 567436            2.0  871f1b464ffffff  871f1b464ffffff
# 567437            2.0  871f1b464ffffff  871f1b464ffffff
# 567438            2.0  871f1b096ffffff  871f1b096ffffff
#
# [567439 rows x 40 columns]

# %%
df.to_csv(os.path.join(os.getcwd(), "..", "data", "output", "Trips.csv"))
